# %% [markdown]
# # Delta Rule
# The Delta Rule is a gradient descent approximator that can be used to find the weight values of a Perceptron. The Delta Rule minimizes an error function (tipically $E=\frac{1}{2}(y - t)^{2}$) by adapting the weight connections in small steps. The step length is defined by the learning rate $\alpha$. In this notebook you will explore the classification capabilities of a single Perceptron by using the delta rule. You will start by setting the connection weights by hand for a simple problem, and then you will apply the delta rule for the same problem, and others.

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
import matplotlib.pyplot as pl
from ipywidgets import interact, widgets

from matplotlib import animation

# %% [markdown]
# ## Loading the Perceptron code
# In order to the make this nothebook smaller, some of the functions (activation functions, and some of the code allowing the visualization of the results) was implemented in a separate python file. You are free to open it if needed.

# %%
import perceptron as pt

# %% [markdown]
# ## The Dataset
# The following script allows you to create a 2D dataset by using the mouse. The left click adds points belonging to class A (blue), and the right click adds points belonging to class B (red). You can create as many points as you desire. The final dataset will contain hence three values per point: x coordinate (-1 ≤ x ≤ 1), y coordinate (-1 ≤ y ≤ 1) and the class ∈ {1,-1}.

# %%
# %matplotlib notebook

fig = pl.figure(figsize=(6,6))
pl.title("Input Dataset")
pl.xlim((-1.2,1.2))
pl.ylim((-1.2,1.2))

dataset = []

def onclick(event):
    global dataset
    cx = event.xdata
    cy = event.ydata
    co = event.button
    dataset.append((cx, cy, co-2))

    pl.scatter(cx, cy, c=(['b', 'r'])[co > 2], s=100, lw=0)
    pl.grid(True)


cid = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig.canvas.mpl_disconnect(onclick)

# %% [markdown]
# This is the dataset you just created. Check that there are no NaNs in the third column. Create once again the dataset if necessary

# %%
# Fixing Error with Corrupted Data at None 
for i in range(0,len(dataset)):
    if (dataset[i] == (None, None, -1)) or (dataset[i] == (None, None, 1)):
        del dataset[i]

dataset
# Out:
# [(-0.24967741935483856, 1.0324134331244927, -1),
#  (0.034193548387096984, 1.011634212345272, -1),
#  (0.18387096774193568, 0.9908549915660512, -1),
#  (0.39032258064516157, 0.9804653811764408, -1),
#  (0.7412903225806455, 0.9700757707868304, -1),
#  (0.8393548387096774, 0.9648809655920254, -1),
#  (1.040645161290323, 0.9285173292283888, -1),
#  (0.9374193548387098, 0.8973484980595576, -1),
#  (0.3696774193548389, 0.8557900565011161, -1),
#  (0.10129032258064541, 0.8454004461115057, -1),
#  (-0.1670967741935483, 0.8298160305270903, -1),
#  (-0.3322580645161288, 0.7986471993582591, -1),
#  (-0.2961290322580643, 0.7986471993582591, -1),
#  (-0.15677419354838684, 0.7778679785790383, -1),
#  (0.29225806451612923, 0.7622835629946225, -1),
#  (0.6070967741935487, 0.7570887577998175, -1),
#  (0.8548387096774195, 0.7518939526050121, -1),
#  (1.09741935483871, 0.7103355110465706, -1),
#  (0.8600000000000003, 0.7051407058517656, -1),
#  (0.4419354838709677, 0.6895562902673498, -1),
#  (0.0393548387096776, 0.6687770694881294, -1),
#  (-0.2599999999999998, 0.6272186279296879, -1),
#  (-0.07935483870967719, 0.5700757707868305, -1),
#  (0.7309677419354839, 0.5337121344231943, -1),
#  (1.0612903225806454, 0.5025433032543631, -1),
#  (None, None, -1),
#  (0.7722580645161292, 0.48176408247514235, -1),
#  (0.15290322580645177, 0.46098486169592157, -1),
#  (-0.05354838709677412, 0.4090368097478694, -1),
#  (-0.2651612903225804, 0.32591992663098646, -1),
#  (0.23548387096774204, 0.2739718746829345, -1),
#  (0.9838709677419355, 0.2428030435141033, -1),
#  (1.1954838709677422, 0.23241343312449292, -1),
#  (1.1335483870967744, 0.22202382273488253, -1),
#  (0.4006451612903228, 0.22202382273488253, -1),
#  (0.1941935483870969, 0.22202382273488253, -1),
#  (-0.28064516129032246, 0.21682901754007733, -1),
#  (-0.316774193548387, 0.20643940715046694, -1),
#  (0.13741935483870993, 0.18046538117644095, -1),
#  (0.7000000000000002, 0.14410174481280458, -1),
#  (0.9529032258064518, 0.1181277188387786, -1),
#  (1.040645161290323, 0.08695888766994742, -1),
#  (0.8445161290322583, 0.06617966689072663, -1),
#  (0.3490322580645162, 0.024621225332285057, -1),
#  (-0.05354838709677412, -0.027326826615766908, -1),
#  (-0.24967741935483856, -0.07408007336901368, -1),
#  (-0.31161290322580637, -0.10005409934303966, -1),
#  (0.26645161290322594, -0.13122293051187084, -1),
#  (0.9167741935483873, -0.1727813720703124, -1),
#  (1.1283870967741936, -0.1727813720703124, -1),
#  (1.1438709677419356, -0.1831709824599228, -1),
#  (0.890967741935484, -0.1935605928495332, -1),
#  (0.338709677419355, -0.23511903440797477, -1),
#  (-0.05354838709677412, -0.27667747596641634, -1),
#  (-0.18774193548387075, -0.3286255279144681, -1),
#  (-0.1670967741935483, -0.35979435908329926, -1),
#  (0.48322580645161306, -0.41174241103135123, -1),
#  (0.963225806451613, -0.432521631810572, -1),
#  (None, None, -1),
#  (0.5606451612903229, -0.4688852681742084, -1),
#  (0.08580645161290334, -0.5000540993430396, -1),
#  (-0.2909677419354837, -0.536417735706676, -1),
#  (-0.36838709677419335, -0.5571969564858967, -1),
#  (-0.09999999999999987, -0.5571969564858967, -1),
#  (0.5245161290322584, -0.5571969564858967, -1),
#  (0.9374193548387098, -0.5935605928495331, -1),
#  (1.0819354838709678, -0.6143398136287539, -1),
#  (0.8754838709677419, -0.6195346188235591, -1),
#  (0.17870967741935506, -0.723430722719663, -1),
#  (-0.17741935483870952, -0.6818722811612214, -1),
#  (-0.5077419354838708, -0.7338203331092734, -1),
#  (-0.37354838709677396, -0.7597943590832994, -1),
#  (0.060000000000000275, -0.7649891642781046, -1),
#  (0.4316129032258065, -0.775378774667715, -1),
#  (0.9116129032258065, -0.8169372162261566, -1),
#  (0.9993548387096776, -0.832521631810572, -1),
#  (0.8135483870967746, -0.858495657784598, -1),
#  (0.6793548387096777, -0.8740800733690136, -1),
#  (0.12193548387096786, -0.9520021512910916, -1),
#  (-0.12580645161290316, -0.9675865668755071, -1),
#  (0.1322580645161291, -1.0143398136287538, -1),
#  (0.4935483870967743, -1.0351190344079746, -1),
#  (0.8754838709677419, -1.0558982551871954, -1),
#  (0.9993548387096776, -1.0610930603820008, -1),
#  (0.5761290322580646, -1.071482670771611, -1),
#  (0.3180645161290325, -1.0922618915508318, -1),
#  (0.20451612903225813, -1.097456696745637, -1),
#  (0.6277419354838711, -1.1130411123300525, -1),
#  (0.9374193548387098, -1.1182359175248577, -1),
#  (1.040645161290323, -1.1130411123300525, -1),
#  (0.1941935483870969, -0.35979435908329926, -1),
#  (-0.621290322580645, -0.38057357986252005, -1),
#  (-0.36322580645161273, -0.4221320214209616, -1),
#  (-0.7399999999999999, -0.38057357986252005, -1),
#  (-0.7399999999999999, -0.29745669674563713, -1),
#  (-0.869032258064516, -0.12083332012226045, -1),
#  (-1.0548387096774192, 0.014231614942674664, -1),
#  (-1.0754838709677417, 0.03501083572189545, -1),
#  (-1.085806451612903, 0.08695888766994742, -1),
#  (-1.116774193548387, 0.16488096559202536, -1),
#  (-1.1270967741935483, 0.2739718746829345, -1),
#  (-1.1477419354838707, 0.44020564091670056, -1),
#  (-1.116774193548387, 0.5908549915660513, -1),
#  (-1.0909677419354837, 0.9181277188387784, -1),
#  (-1.0909677419354837, 1.0739718746829343, -1),
#  (-0.9774193548387096, 1.110335511046571, -1),
#  (-0.4974193548387096, 0.95968616039722, -1),
#  (-0.43032258064516116, 0.9492965500076096, -1),
#  (-0.9103225806451611, 0.9285173292283888, -1),
#  (-0.9567741935483869, 0.8246212253322849, -1),
#  (-0.4767741935483869, 0.8557900565011161, -1),
#  (-0.7141935483870966, 0.6168290175400775, -1),
#  (-0.7193548387096772, 0.9752705759816358, -1),
#  (-0.8277419354838708, 0.47137447208553196, -1),
#  (-0.8380645161290321, 0.2843614850725449, -1),
#  (-0.7399999999999999, 0.7363095370205968, -1),
#  (-0.7658064516129031, 0.47137447208553196, -1),
#  (-0.7761290322580644, 0.22202382273488253, -1),
#  (-0.7193548387096772, 0.12332252403358379, -1),
#  (-0.6419354838709675, 0.12332252403358379, -1),
#  (-0.5903225806451611, 0.3778679785790382, -1),
#  (-0.48709677419354813, 0.6272186279296879, -1),
#  (-0.3012903225806449, 0.6064394071504671, -1),
#  (0.2251612903225808, 0.47656927728033693, -1),
#  (0.6174193548387099, 0.5648809655920255, -1),
#  (0.963225806451613, 0.902543303254363, -1),
#  (None, None, -1),
#  (1.040645161290323, 1.0687770694881293, -1),
#  (0.6690322580645165, 1.0324134331244927, -1),
#  (-0.2909677419354837, 1.0012446019556616, -1),
#  (-0.7916129032258062, 1.0531926539037135, -1),
#  (-0.24967741935483856, 1.0739718746829343, -1),
#  (0.5761290322580646, 1.0376082383192982, -1),
#  (0.9890322580645163, 0.9960497967608566, -1),
#  (0.5451612903225809, 0.5337121344231943, -1),
#  (-0.45612903225806445, 0.14410174481280458, -1),
#  (-0.5335483870967741, -0.13122293051187084, -1),
#  (-0.4664516129032257, -0.24031383960277997, -1),
#  (-0.5232258064516127, 0.23241343312449292, -1),
#  (-0.5593548387096772, 0.5389069396179993, -1),
#  (0.15290322580645177, -0.02213202142096171, -1),
#  (-0.6729032258064515, -0.14680734609628643, -1),
#  (-0.5903225806451611, 0.14929655000760977, -1),
#  (-0.1980645161290322, -0.188365787654728, -1),
#  (-0.7245161290322579, 0.30514070585176567, -1),
#  (0.1322580645161291, 0.21682901754007733, -1),
#  (-0.21870967741935465, -0.0429112422001825, -1),
#  (0.18387096774193568, 0.055790056501116236, -1),
#  (0.3696774193548389, -0.2091450084339488, -1),
#  (0.6380645161290324, -0.09485929414823446, -1),
#  (0.6690322580645165, -0.28187228116122154, -1),
#  (0.7206451612903226, 0.2583874590985189, -1),
#  (0.7000000000000002, 0.06617966689072663, -1),
#  (-0.9103225806451611, -0.9987553980443383, 1),
#  (-0.9980645161290321, -1.1182359175248577, 1),
#  (-1.0187096774193547, -1.1078463071352473, 1),
#  (-1.116774193548387, -0.9831709824599227, 1),
#  (-1.0703225806451613, -0.6662878655768059, 1),
#  (-1.0341935483870968, -0.5883657876547279, 1),
#  (-1.0496774193548384, -0.35979435908329926, 1),
#  (-1.0032258064516126, -0.3390151383040785, 1),
#  (-0.8793548387096772, -0.832521631810572, 1),
#  (-0.7761290322580644, -0.8948592941482344, 1),
#  (-0.5593548387096772, -1.0351190344079746, 1),
#  (-0.24451612903225795, -1.1078463071352473, 1),
#  (0.06516129032258089, -1.1338203331092733, 1),
#  (0.21483870967741958, -1.1286255279144681, 1),
#  (-0.2599999999999998, -0.9935605928495331, 1),
#  (-0.5232258064516127, -0.8948592941482344, 1),
#  (-0.7399999999999999, -0.6714826707716111, 1),
#  (-0.796774193548387, -0.4792748785638188, 1),
#  (-0.9774193548387096, -0.26628786557680595, 1),
#  (-0.6316129032258063, -0.4948592941482344, 1),
#  (-0.7761290322580644, -0.6922618915508318, 1),
#  (-0.7141935483870966, -0.8688852681742084, 1),
#  (-0.43548387096774177, -1.0143398136287538, 1),
#  (-0.1670967741935483, -0.9935605928495331, 1),
#  (-0.24451612903225795, -0.9416125409014812, 1),
#  (-0.22387096774193527, -1.0922618915508318, 1),
#  (0.060000000000000275, -1.0143398136287538, 1),
#  (0.0703225806451615, -0.9831709824599227, 1),
#  (-0.2651612903225804, -0.6351190344079747, 1),
#  (-0.36838709677419335, -0.5987553980443383, 1),
#  (-0.7761290322580644, -0.5260281253170656, 1),
#  (-0.7761290322580644, -0.6091450084339487, 1),
#  (-0.4664516129032257, -0.5571969564858967, 1),
#  (-0.43548387096774177, -0.4688852681742084, 1),
#  (-0.7554838709677417, -0.3182359175248579, 1),
#  (-0.8070967741935482, -0.21433981362875398, 1),
#  (-0.9722580645161288, 0.055790056501116236, 1),
#  (-1.029032258064516, 0.18566018637124615, 1),
#  (-1.085806451612903, 0.32591992663098646, 1),
#  (-1.0961290322580644, 0.41942642013747977, 1),
#  (-1.1064516129032256, 0.5389069396179993, 1),
#  (-1.0909677419354837, 0.715530316241376, 1),
#  (-1.0909677419354837, 0.7622835629946225, 1),
#  (-1.1064516129032256, 0.9700757707868304, 1),
#  (-1.1219354838709676, 1.094751095462155, 1),
#  (-1.1219354838709676, 1.094751095462155, 1),
#  (-1.0496774193548384, 1.0687770694881293, 1),
#  (-0.941290322580645, 0.9441017448128046, 1),
#  (-0.8174193548387095, 0.6791666798777394, 1),
#  (-0.7193548387096772, 0.6064394071504671, 1),
#  (-0.5799999999999998, 0.41942642013747977, 1),
#  (-0.518064516129032, 0.3570887577998174, 1),
#  (-0.43548387096774177, 0.30514070585176567, 1),
#  (-0.28064516129032246, 0.20124460195566174, 1),
#  (-0.17741935483870952, 0.05059525130631104, 1),
#  (-0.11548387096774171, -0.006547605836546122, 1),
#  (-0.05354838709677412, -0.11044370973265005, 1),
#  (0.09096774193548396, -0.26109306038200075, 1),
#  (0.17870967741935506, -0.34940474869368887, 1),
#  (0.3438709677419356, -0.4792748785638188, 1),
#  (0.4367741935483873, -0.5468073460962863, 1),
#  (0.632903225806452, -0.7026515019404422, 1),
#  (0.7309677419354839, -0.8273268266157668, 1),
#  (0.9270967741935485, -0.9520021512910916, 1),
#  (1.0251612903225809, -1.04031383960278, 1),
#  (1.1232258064516132, -1.1286255279144681, 1),
#  (0.9580645161290322, -1.1597943590832993, 1),
#  (0.7103225806451614, -1.1597943590832993, 1),
#  (0.5090322580645164, -1.1545995538884941, 1),
#  (0.2870967741935486, -1.1390151383040785, 1),
#  (0.5554838709677421, -1.1078463071352473, 1),
#  (0.6019354838709678, -0.9208333201222604, 1),
#  (0.39032258064516157, -0.9312229305118708, 1),
#  (0.27677419354838717, -0.9312229305118708, 1),
#  (0.35935483870967766, -0.8169372162261566, 1),
#  (-0.038064516129032056, -0.8273268266157668, 1),
#  (0.15290322580645177, -0.7130411123300526, 1),
#  (-0.04322580645161267, -0.7286255279144682, 1),
#  (-0.15677419354838684, -0.8273268266157668, 1),
#  (0.06516129032258089, -0.6195346188235591, 1),
#  (0.049677419354838825, -0.5208333201222604, 1),
#  (-0.13096774193548377, -0.5883657876547279, 1),
#  (0.008387096774193692, -0.37537877466771485, 1),
#  (-0.15677419354838684, -0.29745669674563713, 1),
#  (-0.316774193548387, -0.4221320214209616, 1),
#  (-0.15677419354838684, -0.21953461882355918, 1),
#  (-0.4767741935483869, -0.26109306038200075, 1),
#  (-0.4148387096774191, -0.3130411123300527, 1),
#  (-0.46129032258064506, -0.05330085258979289, 1),
#  (-0.621290322580645, -0.26628786557680595, 1),
#  (-0.3580645161290321, -0.14161254090148123, 1),
#  (-0.5748387096774192, -0.006547605836546122, 1),
#  (-0.3580645161290321, -0.13122293051187084, 1),
#  (-0.46129032258064506, 0.2583874590985189, 1),
#  (-0.693548387096774, 0.03501083572189545, 1),
#  (-0.5799999999999998, 0.055790056501116236, 1),
#  (-0.7451612903225805, -0.09485929414823446, 1),
#  (-0.48709677419354813, 0.03501083572189545, 1),
#  (-0.7761290322580644, -0.016937216226156515, 1),
#  (-0.6832258064516127, 0.1129329136439734, 1),
#  (-0.6832258064516127, 0.09215369286475261, 1),
#  (-0.7399999999999999, 0.21682901754007733, 1),
#  (-0.8174193548387095, 0.372673173384233, 1),
#  (-0.8896774193548386, 0.5129329136439735, 1),
#  (-0.8999999999999998, 0.5908549915660513, 1),
#  (-0.9516129032258063, 0.715530316241376, 1),
#  (-0.9258064516129031, 0.2739718746829345, 1),
#  (-0.9103225806451611, 0.18566018637124615, 1),
#  (-0.7864516129032256, 0.07137447208553183, 1),
#  (-0.6522580645161289, -0.0429112422001825, 1),
#  (-0.33741935483870944, -0.3338203331092733, 1),
#  (-0.1670967741935483, -0.4273268266157668, 1),
#  (0.17354838709677445, -0.6507034499923903, 1),
#  (0.32838709677419375, -0.7390151383040786, 1),
#  (0.5090322580645164, -0.8481060473949876, 1),
#  (-0.15161290322580623, -0.9831709824599227, 1),
#  (-0.5903225806451611, -1.1130411123300525, 1),
#  (-0.6832258064516127, -1.1130411123300525, 1),
#  (-0.7399999999999999, -1.1078463071352473, 1),
#  (-0.9567741935483869, -0.9987553980443383, 1),
#  (-1.0754838709677417, -0.7545995538884942, 1),
#  (-1.085806451612903, -0.6143398136287539, 1),
#  (-1.029032258064516, -0.26109306038200075, 1),
#  (-1.0187096774193547, -0.16758656687550721, 1),
#  (-0.7761290322580644, -0.13122293051187084, 1),
#  (-0.6316129032258063, 0.06617966689072663, 1),
#  (-0.7038709677419354, 0.3830627837738434, 1),
#  (-0.445806451612903, 0.014231614942674664, 1),
#  (-0.14645161290322561, -0.22472942401836438, 1),
#  (0.15290322580645177, -0.4429112422001824, 1),
#  (0.2870967741935486, -0.5987553980443383, 1),
#  (0.41612903225806486, -0.7286255279144682, 1),
#  (0.5141935483870967, -0.8169372162261566, 1),
#  (0.18387096774193568, -0.6351190344079747, 1),
#  (-0.22903225806451588, -0.4429112422001824, 1),
#  (-0.40451612903225787, -0.0429112422001825, 1),
#  (1.092258064516129, -0.8948592941482344, 1),
#  (1.092258064516129, -0.8948592941482344, 1),
#  (1.0716129032258066, -0.7390151383040786, 1),
#  (1.0767741935483874, -0.723430722719663, 1),
#  (1.092258064516129, -0.5935605928495331, 1),
#  (1.09741935483871, -0.40654760583654603, 1),
#  (1.09741935483871, -0.3390151383040785, 1),
#  (1.112903225806452, -0.27667747596641634, 1),
#  (1.112903225806452, -0.27667747596641634, 1),
#  (1.1025806451612903, -0.1935605928495332, 1),
#  (1.1283870967741936, -0.048106047394987694, 1),
#  (1.1180645161290323, 0.03501083572189545, 1),
#  (1.1283870967741936, 0.14410174481280458, 1),
#  (1.1438709677419356, 0.2947510954621553, 1),
#  (1.1232258064516132, 0.2739718746829345, 1),
#  (1.0767741935483874, 0.2947510954621553, 1),
#  (0.9374193548387098, 0.3830627837738434, 1),
#  (0.818709677419355, 0.5233225240335839, 1),
#  (0.6380645161290324, 0.663582264293324, 1),
#  (0.5606451612903229, 0.7622835629946225, 1),
#  (0.4883870967741939, 0.8661796668907265, 1),
#  (0.4522580645161294, 0.8973484980595576, 1),
#  (0.3800000000000001, 0.9648809655920254, 1),
#  (0.32838709677419375, 1.0220238227348823, 1),
#  (0.21483870967741958, 1.094751095462155, 1),
#  (0.18387096774193568, 1.1155303162413759, 1),
#  (0.08064516129032273, 1.1311147318257917, 1),
#  (-0.17741935483870952, 1.141504342215402, 1),
#  (-0.3012903225806449, 1.146699147410207, 1),
#  (-0.5541935483870966, 1.1311147318257917, 1),
#  (-0.7399999999999999, 1.1311147318257917, 1),
#  (-0.8999999999999998, 1.1311147318257917, 1),
#  (-1.0187096774193547, 1.1155303162413759, 1),
#  (-0.9929032258064514, 1.1155303162413759, 1),
#  (-0.9258064516129031, 1.0895562902673501, 1),
#  (-0.7864516129032256, 0.9233225240335838, 1),
#  (-0.693548387096774, 0.8038420045530641, 1),
#  (-0.6264516129032256, 0.6999459006569602, 1),
#  (-0.4664516129032257, 0.5544913552024151, 1),
#  (-0.34258064516129005, 0.398647199358259, 1),
#  (-0.20838709677419343, 0.23241343312449292, 1),
#  (-0.13096774193548377, 0.18566018637124615, 1),
#  (0.013548387096774306, 0.03501083572189545, 1),
#  (0.15290322580645177, -0.16758656687550721, 1),
#  (0.23032258064516142, -0.22472942401836438, 1),
#  (0.4625806451612906, -0.4636904629794032, 1),
#  (0.5606451612903229, -0.536417735706676, 1),
#  (0.8032258064516129, -0.6922618915508318, 1),
#  (0.8651612903225807, -0.723430722719663, 1),
#  (0.9683870967741939, -0.7805735798625202, 1),
#  (0.9787096774193551, -0.6507034499923903, 1),
#  (1.0251612903225809, -0.38057357986252005, 1),
#  (0.9993548387096776, -0.2091450084339488, 1),
#  (0.9529032258064518, -0.0377164370053773, 1),
#  (0.9374193548387098, 0.055790056501116236, 1),
#  (0.8238709677419358, -0.35979435908329926, 1),
#  (0.818709677419355, -0.34940474869368887, 1),
#  (0.8445161290322583, 0.1129329136439734, 1),
#  (0.6948387096774193, -0.21433981362875398, 1),
#  (0.7103225806451614, -0.39096319025213044, 1),
#  (0.7206451612903226, -0.16239176168070202, 1),
#  (0.6535483870967744, -0.4221320214209616, 1),
#  (0.5348387096774196, -0.25589825518719556, 1),
#  (0.6690322580645165, 0.07137447208553183, 1),
#  (0.689677419354839, 0.1077381084491682, 1),
#  (0.5141935483870967, -0.22472942401836438, 1),
#  (0.6174193548387099, 0.23241343312449292, 1),
#  (0.6019354838709678, 0.23760823831929812, 1),
#  (0.4625806451612906, -0.07408007336901368, 1),
#  (0.4419354838709677, -0.13122293051187084, 1),
#  (0.4367741935483873, -0.11563851492745525, 1),
#  (0.5451612903225809, 0.2947510954621553, 1),
#  (0.5451612903225809, 0.30514070585176567, 1),
#  (0.4935483870967743, 0.01942642013747986, 1),
#  (0.5761290322580646, 0.42462122533228497, 1),
#  (0.4522580645161294, 0.3674783681894278, 1),
#  (0.23548387096774204, -0.0013528006417409255, 1),
#  (0.2251612903225808, 0.2583874590985189, 1),
#  (0.3077419354838711, 0.6064394071504671, 1),
#  (-0.06387096774193535, 0.2428030435141033, 1),
#  (0.06516129032258089, 0.41942642013747977, 1),
#  (0.2251612903225808, 0.5544913552024151, 1),
#  (0.3077419354838711, 0.5492965500076097, 1),
#  (0.17870967741935506, 0.2531926539037137, 1),
#  (-0.027741935483870828, 0.2739718746829345, 1),
#  (0.08580645161290334, 0.44540044611150575, 1),
#  (0.2870967741935486, 0.6272186279296879, 1),
#  (0.13741935483870993, 0.2739718746829345, 1),
#  (-0.00709677419354815, 0.45059525130631095, 1),
#  (0.09096774193548396, 0.6272186279296879, 1),
#  (0.3180645161290325, 0.6168290175400775, 1),
#  (0.17354838709677445, 0.346699147410207, 1),
#  (-0.2032258064516128, 0.4973484980595577, 1),
#  (-0.28064516129032246, 0.6999459006569602, 1),
#  (-0.37354838709677396, 0.7726731733842329, 1),
#  (-0.40451612903225787, 0.8246212253322849, 1),
#  (-0.4767741935483869, 0.8869588876699472, 1),
#  (-0.6109677419354838, 0.9181277188387784, 1),
#  (-0.24967741935483856, 0.902543303254363, 1),
#  (0.10645161290322602, 0.9233225240335838, 1),
#  (0.15806451612903238, 0.8869588876699472, 1),
#  (-0.316774193548387, 0.8557900565011161, 1),
#  (0.049677419354838825, 0.8661796668907265, 1),
#  (0.18387096774193568, 0.8557900565011161, 1),
#  (0.17870967741935506, 0.720725121436181, 1),
#  (0.013548387096774306, 0.6376082383192982, 1),
#  (-0.15161290322580623, 0.5908549915660513, 1),
#  (0.32838709677419375, 0.8869588876699472, 1),
#  (0.4367741935483873, 0.7726731733842329, 1),
#  (0.5554838709677421, 0.6064394071504671, 1),
#  (0.6793548387096777, 0.44020564091670056, 1),
#  (0.7980645161290325, 0.2895562902673501, 1),
#  (0.7980645161290325, 0.21163421234527213, 1),
#  (0.8445161290322583, 0.14410174481280458, 1),
#  (0.8754838709677419, 0.07137447208553183, 1),
#  (0.410967741935484, 0.03501083572189545, 1),
#  (-0.4096774193548385, -0.14161254090148123, 1),
#  (-0.5748387096774192, -0.08966448895342927, 1),
#  (-0.7864516129032256, 0.024621225332285057, 1),
#  (-0.22903225806451588, 0.07137447208553183, -1),
#  (-0.36322580645161273, 0.21163421234527213, -1),
#  (-0.7141935483870966, 0.14410174481280458, -1),
#  (-0.2032258064516128, -0.432521631810572, -1),
#  (0.14258064516129054, -0.484469683758624, -1),
#  (0.5451612903225809, -0.3338203331092733, -1),
#  (-0.012258064516128764, 0.23760823831929812, -1),
#  (-0.1722580645161289, 0.3674783681894278, -1),
#  (-0.001935483870967536, 0.44540044611150575, -1),
#  (0.5658064516129033, 0.1181277188387786, -1),
#  (0.6690322580645165, -0.1727813720703124, -1),
#  (0.8754838709677419, -0.6091450084339487, -1),
#  (0.8600000000000003, -0.7649891642781046, -1),
#  (1.0251612903225809, -0.832521631810572, -1),
#  (1.1335483870967744, -0.9935605928495331, -1),
#  (1.0561290322580645, -0.6455086447975851, -1),
#  (0.8238709677419358, -0.24031383960277997, -1),
#  (0.21483870967741958, 0.3570887577998174, -1),
#  (-0.14645161290322561, 0.42981603052709016, -1),
#  (-0.03290322580645144, 0.7830627837738433, -1),
#  (-0.3012903225806449, 0.8557900565011161, -1),
#  (-0.8174193548387095, 0.8298160305270903, -1),
#  (-0.7399999999999999, 0.6479978487089086, -1),
#  (0.10129032258064541, 0.4973484980595577, -1),
#  (-0.37354838709677396, 0.07137447208553183, -1),
#  (0.7103225806451614, -0.41174241103135123, -1),
#  (0.7877419354838713, -0.6922618915508318, -1),
#  (0.4419354838709677, -0.8948592941482344, -1),
#  (0.21483870967741958, -0.9312229305118708, -1),
#  (-0.022580645161290214, -0.9260281253170656, -1),
#  (-0.3580645161290321, -0.7442099434988838, -1),
#  (-0.518064516129032, -0.5000540993430396, -1),
#  (-0.6832258064516127, -0.35979435908329926, -1),
#  (-0.9051612903225805, 0.024621225332285057, -1),
#  (-0.9206451612903224, 0.31553031624137606, -1),
#  (-0.8174193548387095, 0.7363095370205968, -1),
#  (0.26645161290322594, 0.7103355110465706, -1),
#  (0.6380645161290324, 0.46098486169592157, -1)]

# %% [markdown]
# ## Finding the weights by hand
# In this section you should try to find the set of weights that allows a Perceptron to separate the two classes you previously defined. Use the sliders to modify the value of each one of the connections and the bias of the Perceptron while trying to separate the two classes (blue and red). The curve on the right represents the classification error (MSE). If the modifications you provide improve the classification, you should see the error decreasing.

# %% [raw]
#             ______________
#            /              \
# x __w_x__ j                l
#   _______ | f_act(I.W + b) |------ output
# y   w_y   l                j
#            \______________/
# Where:
# x = input x
# y = input y
# b = bias
# f_act = activation function
# I = vector of inputs
# W = vector of weights

# %%
plotter = pt.PerceptronPlotter2D(data=np.asarray(dataset))

# %%
# %matplotlib inline
_= interact(plotter.plot_interactive, **plotter.controls)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='Weight x:', max=2.0, min=-2.0, step=0.01), FloatSlid…

# %% [markdown]
# ## The Delta Rule
# In the following step we propose to solve the classification problem you defined by using the delta-rule algorithm. Look at the code in compute_delta_w and try to understand it.

# %% [raw]
#             ______________
#            /              \
# x __w_x__ j                l
#   _______ | f_act(I.W + b) |------ output
# y   w_y   l                j
#            \______________/
# Where:
# x = input x
# y = input y
# b = bias
# f_act = activation function
# I = vector of inputs
# W = vector of weights

# %% [markdown]
# $$ neta = (x * w\_x) + (y * w\_y) + b$$
# $$ output = f\_act(neta) $$
# $$ \Delta w\_x = \alpha * (target - output) * f\_act'(neta) * x $$
# $$ \Delta w\_y = \alpha * (target - output) * f\_act'(neta) * y $$
# $$ \Delta b = \alpha * (target - output) * f\_act'(neta) $$

# %%
def compute_delta_w(inputs, weights, bias, targets, alpha, activation_function):
    neta = np.dot(inputs, weights) + bias
    output, d_output = activation_function(neta)
    error = targets - output
    d_w_x = alpha * error * d_output * inputs[:,0]
    d_w_y = alpha * error * d_output * inputs[:,1]
    d_b = alpha * error * d_output
    return [d_w_x, d_w_y, d_b]

# %% [markdown]
# ## Batch learning
# When you launch the cell, the weights and the bias are initialized at random, and the algorithm perform some iterations (NUMBER_OF_EPOCHS) doing the following:
# +  for each point in the dataset, compute the modifications ( Δw ) to be done at each parameter in order to minimize the error function
# + sum up all the modifications -> batch policy
# + modify the weights and bias of the perceptron
#
# The cell records the effects of the modifications performed in a video. Therefore, you can visualize the learning process afterwards.

# %%
# %matplotlib inline

inputs = np.asarray(dataset)[:,0:2]
targets = np.asarray(dataset)[:,2]
weights = np.random.normal(size=2)
bias = np.random.normal(size=1)
activation_function = pt.htan

ALPHA = 0.1
NUMBER_OF_EPOCHS = 30

fig = pl.figure(figsize=(12, 4))
plotter = pt.PerceptronPlotter2D(data=np.asarray(dataset))
plotter.init_animation()

def run_epoch_batch(i, alpha, inputs, weights, bias, targets, activation_function):
    d_w_x, d_w_y, d_b = compute_delta_w(inputs, weights, bias, targets, ALPHA, activation_function)
    weights += np.array([np.sum(d_w_x), np.sum(d_w_y)])
    bias += np.sum(d_b)
    
    return plotter.data2animation(i, inputs, weights, bias, targets, activation_function)

SHOW_VIDEO = False       # change this flag if you are unable to see the video
if SHOW_VIDEO:
    anim = animation.FuncAnimation(fig, run_epoch_batch, fargs=(ALPHA, inputs, weights, bias, targets, activation_function), frames=NUMBER_OF_EPOCHS, interval=20, blit=True)
    pt.display_animation(anim)
else:
    for i in np.arange(NUMBER_OF_EPOCHS):
        run_epoch_batch(i, ALPHA, inputs, weights, bias, targets, activation_function)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-183534e3d622> in <module>
#      27 else:
#      28     for i in np.arange(NUMBER_OF_EPOCHS):
# ---> 29         run_epoch_batch(i, ALPHA, inputs, weights, bias, targets, activation_function)
#
# <ipython-input-9-183534e3d622> in run_epoch_batch(i, alpha, inputs, weights, bias, targets, activation_function)
#      15
#      16 def run_epoch_batch(i, alpha, inputs, weights, bias, targets, activation_function):
# ---> 17     d_w_x, d_w_y, d_b = compute_delta_w(inputs, weights, bias, targets, ALPHA, activation_function)
#      18     weights += np.array([np.sum(d_w_x), np.sum(d_w_y)])
#      19     bias += np.sum(d_b)
#
# <ipython-input-8-61236adc37e4> in compute_delta_w(inputs, weights, bias, targets, alpha, activation_function)
#       1 def compute_delta_w(inputs, weights, bias, targets, alpha, activation_function):
# ----> 2     neta = np.dot(inputs, weights) + bias
#       3     output, d_output = activation_function(neta)
#       4     error = targets - output
#       5     d_w_x = alpha * error * d_output * inputs[:,0]
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'float'

# %% [markdown]
# ## Exercise
# You are free to modify the learning rate (ALPHA) and the number of iterations (NUMBER_OF_EPOCHS).
#
# Try different 2D classification problems and observe the behaviour of the algorithm in terms of:
# - Learning rate needed
# - Convergence speed
# - Oscillations
#
# Bare in mind that, in the current implementation, the parameters (weights and bias) are initialized randomly every time you launch the cell.
#
# Create some datasets as it is shown, and perform the following tests:
#
# 1. What happens if the boundaries between both classes are well defined?
# ![separable](separable.png)
#
# 2. What happens if the classes overlap? What could you say about oscillations in the error signal?
# ![overlapping](overlapping.png)
#
# 3. What happens if it is not possible to separate the classes with a single line? What could you say about local minima?
# ![non_separable](non_separable.png)
